# %% [markdown]
# Cell 1: Setup and Imports

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Install dependencies
# !pip install -q transformers torch safetensors pytorch-crf scikit-learn

import torch
import json
import numpy as np
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from safetensors.torch import load_file
from sklearn.metrics import precision_recall_fscore_support, accuracy_score
from collections import defaultdict
import torch.nn as nn
from transformers import AutoModel
from torchcrf import CRF

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")

# Set your drive path
drive_path = "/content/drive/MyDrive/intent_project"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Device: cuda

# %% [markdown]
# Cell 2: Define CRF Model Class

# %%
class XLMRobertaWithCRF(nn.Module):
    def __init__(self, model_name, num_labels, id2label, label2id):
        super().__init__()
        self.transformer = AutoModel.from_pretrained(model_name)
        self.dropout = nn.Dropout(0.1)
        self.classifier = nn.Linear(self.transformer.config.hidden_size, num_labels)
        self.crf = CRF(num_labels, batch_first=True)
        self.id2label = id2label
        self.label2id = label2id
        self.num_labels = num_labels

    def forward(self, input_ids, attention_mask, token_type_ids=None, labels=None):
        outputs = self.transformer(
            input_ids=input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids
        )
        sequence_output = outputs
        sequence_output = self.dropout(sequence_output)
        logits = self.classifier(sequence_output)

        if labels is not None:
            labels = torch.where(labels == -100, torch.zeros_like(labels), labels)
            loss = -self.crf(logits, labels, mask=attention_mask.bool(), reduction='mean')
            return {'loss': loss, 'logits': logits}
        else:
            predictions = self.crf.decode(logits, mask=attention_mask.bool())
            return {'logits': logits, 'predictions': predictions}

print("✓ CRF model class defined")
# Out:
# ✓ CRF model class defined

# %% [markdown]
# Cell 3: Load Intent Classification Model

# %%
print("\n=== Loading Intent Classification Model ===")

intent_model_dir = f'{drive_path}/xlm-roberta-intent-classifier-final'

intent_tokenizer = AutoTokenizer.from_pretrained(intent_model_dir)
intent_model = AutoModelForSequenceClassification.from_pretrained(intent_model_dir)
intent_model.to(device)
intent_model.eval()

# Load intent mappings
with open(f'{intent_model_dir}/intent2id.json', 'r') as f:
    intent2id = json.load(f)
with open(f'{intent_model_dir}/id2intent.json', 'r') as f:
    id2intent = json.load(f)

print(f"✓ Intent model loaded ({len(id2intent)} intents)")
# Out:
# === Loading Intent Classification Model ===
# ✓ Intent model loaded (60 intents)

# %% [markdown]
# Cell 4: Load Slot Filling Model

# %%
print("\n=== Loading CRF Slot Filling Model ===")

slot_model_dir = f"{drive_path}/slot_filling_model_crf/final_model"

with open(f"{slot_model_dir}/id2label.json", 'r') as f:
    id2slot = json.load(f)
with open(f"{slot_model_dir}/label2id.json", 'r') as f:
    slot2id = json.load(f)

slot_tokenizer = AutoTokenizer.from_pretrained(slot_model_dir)

slot_model = XLMRobertaWithCRF(
    model_name="xlm-roberta-base",
    num_labels=len(slot2id),
    id2label=id2slot,
    label2id=slot2id
)

model_state = load_file(f"{slot_model_dir}/model.safetensors")
slot_model.load_state_dict(model_state)
slot_model.to(device)
slot_model.eval()

print(f"✓ Slot filling CRF model loaded ({len(slot2id)} labels)")
# Out:
# === Loading CRF Slot Filling Model ===
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# ✓ Slot filling CRF model loaded (111 labels)

# %% [markdown]
# Cell 5: Define Prediction Functions

# %%
def predict_intent(utterance):
    """Predict intent for a single utterance"""
    inputs = intent_tokenizer(
        utterance,
        return_tensors="pt",
        truncation=True,
        max_length=128,
        padding="max_length"
    ).to(device)

    with torch.no_grad():
        outputs = intent_model(**inputs)
        logits = outputs.logits
        pred_id = logits.argmax(dim=-1).item()
        pred_label = id2intent[str(pred_id)]
        return pred_label

def extract_slots_crf(utterance):
    """Extract slots from utterance using CRF model"""
    words = utterance.split()

    inputs = slot_tokenizer(
        words,
        is_split_into_words=True,
        return_tensors="pt",
        truncation=True,
        max_length=128,
        padding="max_length"
    )
    inputs = {k: v.to(device) for k, v in inputs.items()}

    with torch.no_grad():
        # Forward pass
        transformer_outputs = slot_model.transformer(
            input_ids=inputs['input_ids'],
            attention_mask=inputs['attention_mask']
        )
        sequence_output = transformer_outputs[0]  # Extract the sequence output tensor
        sequence_output = slot_model.dropout(sequence_output)
        logits = slot_model.classifier(sequence_output)

        # CRF decode
        predictions = slot_model.crf.decode(logits, mask=inputs['attention_mask'].bool())
        predictions = torch.tensor(predictions[0])

    # Get word IDs for alignment
    batch_encoding = slot_tokenizer(
        words,
        is_split_into_words=True,
        truncation=True,
        max_length=128,
        padding="max_length"
    )
    word_ids = batch_encoding.word_ids(batch_index=0)

    # Map token predictions back to words
    word_predictions = []
    for word_idx in range(len(words)):
        word_preds = []
        for token_idx, wid in enumerate(word_ids):
            if wid == word_idx:
                word_preds.append(predictions[token_idx])
        if word_preds:
            word_predictions.append(word_preds[0].item())

    # Extract slots from BIO tags
    slots = []
    current_slot_type = None
    current_slot_words = []

    for word, pred_id in zip(words, word_predictions):
        label = id2slot[str(int(pred_id))]

        if label == 'O':
            if current_slot_type:
                slots.append({'type': current_slot_type, 'value': ' '.join(current_slot_words)})
                current_slot_type = None
                current_slot_words = []
        elif label.startswith('B-'):
            if current_slot_type:
                slots.append({'type': current_slot_type, 'value': ' '.join(current_slot_words)})
            current_slot_type = label[2:]
            current_slot_words = [word]
        elif label.startswith('I-'):
            slot_type = label[2:]
            if slot_type == current_slot_type:
                current_slot_words.append(word)
            else:
                if current_slot_type:
                    slots.append({'type': current_slot_type, 'value': ' '.join(current_slot_words)})
                current_slot_type = slot_type
                current_slot_words = [word]

    if current_slot_type:
        slots.append({'type': current_slot_type, 'value': ' '.join(current_slot_words)})

    return slots

print("✓ Prediction functions defined (fixed)")
# Out:
# ✓ Prediction functions defined (fixed)

# %% [markdown]
# Cell 6: Load Test Data

# %%
import os
from datasets import load_dataset

# First, verify the path exists
base_path = "/content/drive/MyDrive/intent_project"
test_dir = os.path.join(base_path, "test")

print(f"Looking for test data at: {test_dir}")
print(f"Path exists: {os.path.exists(test_dir)}")

# List contents to see what's there
if os.path.exists(base_path):
    print(f"\nContents of {base_path}:")
    for item in os.listdir(base_path):
        print(f"  - {item}")
# Out:
# Looking for test data at: /content/drive/MyDrive/intent_project/test
# Path exists: True
#
# Contents of /content/drive/MyDrive/intent_project:
#   - project_proposal.docx
#   - .ipynb_checkpoints
#   - data
#   - train
#   - validation
#   - test
#   - xlm-roberta-intent-classifier-final
#   - NLP_IntentClassification.ipynb
#   - combined_nlu_results.json
#   - NLP_CombinedIntent+SlotFilling.ipynb
#   - massive_51_langs_test.json
#   - tokenized_dataset
#   - slot_filling_model
#   - results_intent_classification
#   - team3_crosslingual_eval.json
#   - ner_dataset_plain
#   - tokenized_ner_dataset
#   - slot_filling_model_plaintext
#   - slot_filling_model_crf
#   - SlotFilling_2.ipynb
#   - SlotFilling_CRFvsNonCRF.ipynb
#   - NLP_SlotFilling_1st.ipynb
#   - CombinedIntent_NERSlotCRF.ipynb
#   - app.py
#   - splits
#   - Project_Summary_Document.pages
#   - Project_Summary_Document.pdf

# %%
import os
import json
from datasets import load_from_disk

# Load test split from HuggingFace dataset folder format
test_dir = "/content/drive/MyDrive/intent_project/test"

print(f"Loading test split from: {test_dir}")

# HuggingFace datasets saves splits in a specific format
# Try loading it as a dataset split
try:
    dataset = load_from_disk(test_dir)
    print(f"✓ Loaded dataset from disk")
except:
    print("Trying alternative loading method...")
    # If the above fails, list what's in the folder first
    print(f"\nContents of {test_dir}:")
    for item in os.listdir(test_dir):
        print(f"  - {item}")

# Convert to list of dicts
test_data = []
for item in dataset:
    test_data.append({
        'utt': item.get('utt', ''),
        'intent': item.get('intent', ''),
        'annot_utt': item.get('annot_utt', '')
    })

print(f"✓ Converted to list: {len(test_data)} examples")
if test_data:
    print(f"\nSample test example:")
    print(f"  utt: {test_data[0]['utt']}")
    print(f"  intent: {test_data[0]['intent']}")
    print(f"  annot_utt: {test_data[0]['annot_utt'][:100] if test_data[0]['annot_utt'] else 'N/A'}...")
# Out:
# Loading test split from: /content/drive/MyDrive/intent_project/test
# ✓ Loaded dataset from disk
# ✓ Converted to list: 59480 examples
#
# Sample test example:
#   utt: wake me up at five am this week
#   intent: alarm_set
#   annot_utt: wake me up at [time : five am] [date : this week]...

# %% [markdown]
# Cell 7: Intent Classification Evaluation

# %%
print("\n" + "="*70)
print("INTENT CLASSIFICATION EVALUATION")
print("="*70)

true_intents = []
pred_intents = []

for i, example in enumerate(test_data):
    utterance = example['utt']
    true_intent = example['intent']

    pred_intent = predict_intent(utterance)

    true_intents.append(true_intent)
    pred_intents.append(pred_intent)

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(test_data)} examples...")

# Compute metrics
intent_accuracy = accuracy_score(true_intents, pred_intents)

# Micro-averaged metrics
intent_micro_p, intent_micro_r, intent_micro_f1, _ = precision_recall_fscore_support(
    true_intents, pred_intents, average='micro', zero_division=0
)

# Macro-averaged metrics
intent_macro_p, intent_macro_r, intent_macro_f1, _ = precision_recall_fscore_support(
    true_intents, pred_intents, average='macro', zero_division=0
)

# Weighted-averaged metrics
intent_weighted_p, intent_weighted_r, intent_weighted_f1, _ = precision_recall_fscore_support(
    true_intents, pred_intents, average='weighted', zero_division=0
)

print("\n" + "-"*70)
print("INTENT CLASSIFICATION RESULTS")
print("-"*70)
print(f"Accuracy:           {intent_accuracy:.4f}")
print(f"\nMicro-averaged:")
print(f"  Precision:        {intent_micro_p:.4f}")
print(f"  Recall:           {intent_micro_r:.4f}")
print(f"  F1-Score:         {intent_micro_f1:.4f}")
print(f"\nMacro-averaged:")
print(f"  Precision:        {intent_macro_p:.4f}")
print(f"  Recall:           {intent_macro_r:.4f}")
print(f"  F1-Score:         {intent_macro_f1:.4f}")
print(f"\nWeighted-averaged:")
print(f"  Precision:        {intent_weighted_p:.4f}")
print(f"  Recall:           {intent_weighted_r:.4f}")
print(f"  F1-Score:         {intent_weighted_f1:.4f}")
# Out:
# ======================================================================
# INTENT CLASSIFICATION EVALUATION
# ======================================================================
# Processed 100/59480 examples...
# Processed 200/59480 examples...
# Processed 300/59480 examples...
# Processed 400/59480 examples...
# Processed 500/59480 examples...
# Processed 600/59480 examples...
# Processed 700/59480 examples...
# Processed 800/59480 examples...
# Processed 900/59480 examples...
# Processed 1000/59480 examples...
# Processed 1100/59480 examples...
# Processed 1200/59480 examples...
# Processed 1300/59480 examples...
# Processed 1400/59480 examples...
# Processed 1500/59480 examples...
# Processed 1600/59480 examples...
# Processed 1700/59480 examples...
# Processed 1800/59480 examples...
# Processed 1900/59480 examples...
# Processed 2000/59480 examples...
# Processed 2100/59480 examples...
# Processed 2200/59480 examples...
# Processed 2300/59480 examples...
# Processed 2400/59480 examples...
# Processed 2500/59480 examples...
# Processed 2600/59480 examples...
# Processed 2700/59480 examples...
# Processed 2800/59480 examples...
# Processed 2900/59480 examples...
# Processed 3000/59480 examples...
# Processed 3100/59480 examples...
# Processed 3200/59480 examples...
# Processed 3300/59480 examples...
# Processed 3400/59480 examples...
# Processed 3500/59480 examples...
# Processed 3600/59480 examples...
# Processed 3700/59480 examples...
# Processed 3800/59480 examples...
# Processed 3900/59480 examples...
# Processed 4000/59480 examples...
# Processed 4100/59480 examples...
# Processed 4200/59480 examples...
# Processed 4300/59480 examples...
# Processed 4400/59480 examples...
# Processed 4500/59480 examples...
# Processed 4600/59480 examples...
# Processed 4700/59480 examples...
# Processed 4800/59480 examples...
# Processed 4900/59480 examples...
# Processed 5000/59480 examples...
# Processed 5100/59480 examples...
# Processed 5200/59480 examples...
# Processed 5300/59480 examples...
# Processed 5400/59480 examples...
# Processed 5500/59480 examples...
# Processed 5600/59480 examples...
# Processed 5700/59480 examples...
# Processed 5800/59480 examples...
# Processed 5900/59480 examples...
# Processed 6000/59480 examples...
# Processed 6100/59480 examples...
# Processed 6200/59480 examples...
# Processed 6300/59480 examples...
# Processed 6400/59480 examples...
# Processed 6500/59480 examples...
# Processed 6600/59480 examples...
# Processed 6700/59480 examples...
# Processed 6800/59480 examples...
# Processed 6900/59480 examples...
# Processed 7000/59480 examples...
# Processed 7100/59480 examples...
# Processed 7200/59480 examples...
# Processed 7300/59480 examples...
# Processed 7400/59480 examples...
# Processed 7500/59480 examples...
# Processed 7600/59480 examples...
# Processed 7700/59480 examples...
# Processed 7800/59480 examples...
# Processed 7900/59480 examples...
# Processed 8000/59480 examples...
# Processed 8100/59480 examples...
# Processed 8200/59480 examples...
# Processed 8300/59480 examples...
# Processed 8400/59480 examples...
# Processed 8500/59480 examples...
# Processed 8600/59480 examples...
# Processed 8700/59480 examples...
# Processed 8800/59480 examples...
# Processed 8900/59480 examples...
# Processed 9000/59480 examples...
# Processed 9100/59480 examples...
# Processed 9200/59480 examples...
# Processed 9300/59480 examples...
# Processed 9400/59480 examples...
# Processed 9500/59480 examples...
# Processed 9600/59480 examples...
# Processed 9700/59480 examples...
# Processed 9800/59480 examples...
# Processed 9900/59480 examples...
# Processed 10000/59480 examples...
# Processed 10100/59480 examples...
# Processed 10200/59480 examples...
# Processed 10300/59480 examples...
# Processed 10400/59480 examples...
# Processed 10500/59480 examples...
# Processed 10600/59480 examples...
# Processed 10700/59480 examples...
# Processed 10800/59480 examples...
# Processed 10900/59480 examples...
# Processed 11000/59480 examples...
# Processed 11100/59480 examples...
# Processed 11200/59480 examples...
# Processed 11300/59480 examples...
# Processed 11400/59480 examples...
# Processed 11500/59480 examples...
# Processed 11600/59480 examples...
# Processed 11700/59480 examples...
# Processed 11800/59480 examples...
# Processed 11900/59480 examples...
# Processed 12000/59480 examples...
# Processed 12100/59480 examples...
# Processed 12200/59480 examples...
# Processed 12300/59480 examples...
# Processed 12400/59480 examples...
# Processed 12500/59480 examples...
# Processed 12600/59480 examples...
# Processed 12700/59480 examples...
# Processed 12800/59480 examples...
# Processed 12900/59480 examples...
# Processed 13000/59480 examples...
# Processed 13100/59480 examples...
# Processed 13200/59480 examples...
# Processed 13300/59480 examples...
# Processed 13400/59480 examples...
# Processed 13500/59480 examples...
# Processed 13600/59480 examples...
# Processed 13700/59480 examples...
# Processed 13800/59480 examples...
# Processed 13900/59480 examples...
# Processed 14000/59480 examples...
# Processed 14100/59480 examples...
# Processed 14200/59480 examples...
# Processed 14300/59480 examples...
# Processed 14400/59480 examples...
# Processed 14500/59480 examples...
# Processed 14600/59480 examples...
# Processed 14700/59480 examples...
# Processed 14800/59480 examples...
# Processed 14900/59480 examples...
# Processed 15000/59480 examples...
# Processed 15100/59480 examples...
# Processed 15200/59480 examples...
# Processed 15300/59480 examples...
# Processed 15400/59480 examples...
# Processed 15500/59480 examples...
# Processed 15600/59480 examples...
# Processed 15700/59480 examples...
# Processed 15800/59480 examples...
# Processed 15900/59480 examples...
# Processed 16000/59480 examples...
# Processed 16100/59480 examples...
# Processed 16200/59480 examples...
# Processed 16300/59480 examples...
# Processed 16400/59480 examples...
# Processed 16500/59480 examples...
# Processed 16600/59480 examples...
# Processed 16700/59480 examples...
# Processed 16800/59480 examples...
# Processed 16900/59480 examples...
# Processed 17000/59480 examples...
# Processed 17100/59480 examples...
# Processed 17200/59480 examples...
# Processed 17300/59480 examples...
# Processed 17400/59480 examples...
# Processed 17500/59480 examples...
# Processed 17600/59480 examples...
# Processed 17700/59480 examples...
# Processed 17800/59480 examples...
# Processed 17900/59480 examples...
# Processed 18000/59480 examples...
# Processed 18100/59480 examples...
# Processed 18200/59480 examples...
# Processed 18300/59480 examples...
# Processed 18400/59480 examples...
# Processed 18500/59480 examples...
# Processed 18600/59480 examples...
# Processed 18700/59480 examples...
# Processed 18800/59480 examples...
# Processed 18900/59480 examples...
# Processed 19000/59480 examples...
# Processed 19100/59480 examples...
# Processed 19200/59480 examples...
# Processed 19300/59480 examples...
# Processed 19400/59480 examples...
# Processed 19500/59480 examples...
# Processed 19600/59480 examples...
# Processed 19700/59480 examples...
# Processed 19800/59480 examples...
# Processed 19900/59480 examples...
# Processed 20000/59480 examples...
# Processed 20100/59480 examples...
# Processed 20200/59480 examples...
# Processed 20300/59480 examples...
# Processed 20400/59480 examples...
# Processed 20500/59480 examples...
# Processed 20600/59480 examples...
# Processed 20700/59480 examples...
# Processed 20800/59480 examples...
# Processed 20900/59480 examples...
# Processed 21000/59480 examples...
# Processed 21100/59480 examples...
# Processed 21200/59480 examples...
# Processed 21300/59480 examples...
# Processed 21400/59480 examples...
# Processed 21500/59480 examples...
# Processed 21600/59480 examples...
# Processed 21700/59480 examples...
# Processed 21800/59480 examples...
# Processed 21900/59480 examples...
# Processed 22000/59480 examples...
# Processed 22100/59480 examples...
# Processed 22200/59480 examples...
# Processed 22300/59480 examples...
# Processed 22400/59480 examples...
# Processed 22500/59480 examples...
# Processed 22600/59480 examples...
# Processed 22700/59480 examples...
# Processed 22800/59480 examples...
# Processed 22900/59480 examples...
# Processed 23000/59480 examples...
# Processed 23100/59480 examples...
# Processed 23200/59480 examples...
# Processed 23300/59480 examples...
# Processed 23400/59480 examples...
# Processed 23500/59480 examples...
# Processed 23600/59480 examples...
# Processed 23700/59480 examples...
# Processed 23800/59480 examples...
# Processed 23900/59480 examples...
# Processed 24000/59480 examples...
# Processed 24100/59480 examples...
# Processed 24200/59480 examples...
# Processed 24300/59480 examples...
# Processed 24400/59480 examples...
# Processed 24500/59480 examples...
# Processed 24600/59480 examples...
# Processed 24700/59480 examples...
# Processed 24800/59480 examples...
# Processed 24900/59480 examples...
# Processed 25000/59480 examples...
# Processed 25100/59480 examples...
# Processed 25200/59480 examples...
# Processed 25300/59480 examples...
# Processed 25400/59480 examples...
# Processed 25500/59480 examples...
# Processed 25600/59480 examples...
# Processed 25700/59480 examples...
# Processed 25800/59480 examples...
# Processed 25900/59480 examples...
# Processed 26000/59480 examples...
# Processed 26100/59480 examples...
# Processed 26200/59480 examples...
# Processed 26300/59480 examples...
# Processed 26400/59480 examples...
# Processed 26500/59480 examples...
# Processed 26600/59480 examples...
# Processed 26700/59480 examples...
# Processed 26800/59480 examples...
# Processed 26900/59480 examples...
# Processed 27000/59480 examples...
# Processed 27100/59480 examples...
# Processed 27200/59480 examples...
# Processed 27300/59480 examples...
# Processed 27400/59480 examples...
# Processed 27500/59480 examples...
# Processed 27600/59480 examples...
# Processed 27700/59480 examples...
# Processed 27800/59480 examples...
# Processed 27900/59480 examples...
# Processed 28000/59480 examples...
# Processed 28100/59480 examples...
# Processed 28200/59480 examples...
# Processed 28300/59480 examples...
# Processed 28400/59480 examples...
# Processed 28500/59480 examples...
# Processed 28600/59480 examples...
# Processed 28700/59480 examples...
# Processed 28800/59480 examples...
# Processed 28900/59480 examples...
# Processed 29000/59480 examples...
# Processed 29100/59480 examples...
# Processed 29200/59480 examples...
# Processed 29300/59480 examples...
# Processed 29400/59480 examples...
# Processed 29500/59480 examples...
# Processed 29600/59480 examples...
# Processed 29700/59480 examples...
# Processed 29800/59480 examples...
# Processed 29900/59480 examples...
# Processed 30000/59480 examples...
# Processed 30100/59480 examples...
# Processed 30200/59480 examples...
# Processed 30300/59480 examples...
# Processed 30400/59480 examples...
# Processed 30500/59480 examples...
# Processed 30600/59480 examples...
# Processed 30700/59480 examples...
# Processed 30800/59480 examples...
# Processed 30900/59480 examples...
# Processed 31000/59480 examples...
# Processed 31100/59480 examples...
# Processed 31200/59480 examples...
# Processed 31300/59480 examples...
# Processed 31400/59480 examples...
# Processed 31500/59480 examples...
# Processed 31600/59480 examples...
# Processed 31700/59480 examples...
# Processed 31800/59480 examples...
# Processed 31900/59480 examples...
# Processed 32000/59480 examples...
# Processed 32100/59480 examples...
# Processed 32200/59480 examples...
# Processed 32300/59480 examples...
# Processed 32400/59480 examples...
# Processed 32500/59480 examples...
# Processed 32600/59480 examples...
# Processed 32700/59480 examples...
# Processed 32800/59480 examples...
# Processed 32900/59480 examples...
# Processed 33000/59480 examples...
# Processed 33100/59480 examples...
# Processed 33200/59480 examples...
# Processed 33300/59480 examples...
# Processed 33400/59480 examples...
# Processed 33500/59480 examples...
# Processed 33600/59480 examples...
# Processed 33700/59480 examples...
# Processed 33800/59480 examples...
# Processed 33900/59480 examples...
# Processed 34000/59480 examples...
# Processed 34100/59480 examples...
# Processed 34200/59480 examples...
# Processed 34300/59480 examples...
# Processed 34400/59480 examples...
# Processed 34500/59480 examples...
# Processed 34600/59480 examples...
# Processed 34700/59480 examples...
# Processed 34800/59480 examples...
# Processed 34900/59480 examples...
# Processed 35000/59480 examples...
# Processed 35100/59480 examples...
# Processed 35200/59480 examples...
# Processed 35300/59480 examples...
# Processed 35400/59480 examples...
# Processed 35500/59480 examples...
# Processed 35600/59480 examples...
# Processed 35700/59480 examples...
# Processed 35800/59480 examples...
# Processed 35900/59480 examples...
# Processed 36000/59480 examples...
# Processed 36100/59480 examples...
# Processed 36200/59480 examples...
# Processed 36300/59480 examples...
# Processed 36400/59480 examples...
# Processed 36500/59480 examples...
# Processed 36600/59480 examples...
# Processed 36700/59480 examples...
# Processed 36800/59480 examples...
# Processed 36900/59480 examples...
# Processed 37000/59480 examples...
# Processed 37100/59480 examples...
# Processed 37200/59480 examples...
# Processed 37300/59480 examples...
# Processed 37400/59480 examples...
# Processed 37500/59480 examples...
# Processed 37600/59480 examples...
# Processed 37700/59480 examples...
# Processed 37800/59480 examples...
# Processed 37900/59480 examples...
# Processed 38000/59480 examples...
# Processed 38100/59480 examples...
# Processed 38200/59480 examples...
# Processed 38300/59480 examples...
# Processed 38400/59480 examples...
# Processed 38500/59480 examples...
# Processed 38600/59480 examples...
# Processed 38700/59480 examples...
# Processed 38800/59480 examples...
# Processed 38900/59480 examples...
# Processed 39000/59480 examples...
# Processed 39100/59480 examples...
# Processed 39200/59480 examples...
# Processed 39300/59480 examples...
# Processed 39400/59480 examples...
# Processed 39500/59480 examples...
# Processed 39600/59480 examples...
# Processed 39700/59480 examples...
# Processed 39800/59480 examples...
# Processed 39900/59480 examples...
# Processed 40000/59480 examples...
# Processed 40100/59480 examples...
# Processed 40200/59480 examples...
# Processed 40300/59480 examples...
# Processed 40400/59480 examples...
# Processed 40500/59480 examples...
# Processed 40600/59480 examples...
# Processed 40700/59480 examples...
# Processed 40800/59480 examples...
# Processed 40900/59480 examples...
# Processed 41000/59480 examples...
# Processed 41100/59480 examples...
# Processed 41200/59480 examples...
# Processed 41300/59480 examples...
# Processed 41400/59480 examples...
# Processed 41500/59480 examples...
# Processed 41600/59480 examples...
# Processed 41700/59480 examples...
# Processed 41800/59480 examples...
# Processed 41900/59480 examples...
# Processed 42000/59480 examples...
# Processed 42100/59480 examples...
# Processed 42200/59480 examples...
# Processed 42300/59480 examples...
# Processed 42400/59480 examples...
# Processed 42500/59480 examples...
# Processed 42600/59480 examples...
# Processed 42700/59480 examples...
# Processed 42800/59480 examples...
# Processed 42900/59480 examples...
# Processed 43000/59480 examples...
# Processed 43100/59480 examples...
# Processed 43200/59480 examples...
# Processed 43300/59480 examples...
# Processed 43400/59480 examples...
# Processed 43500/59480 examples...
# Processed 43600/59480 examples...
# Processed 43700/59480 examples...
# Processed 43800/59480 examples...
# Processed 43900/59480 examples...
# Processed 44000/59480 examples...
# Processed 44100/59480 examples...
# Processed 44200/59480 examples...
# Processed 44300/59480 examples...
# Processed 44400/59480 examples...
# Processed 44500/59480 examples...
# Processed 44600/59480 examples...
# Processed 44700/59480 examples...
# Processed 44800/59480 examples...
# Processed 44900/59480 examples...
# Processed 45000/59480 examples...
# Processed 45100/59480 examples...
# Processed 45200/59480 examples...
# Processed 45300/59480 examples...
# Processed 45400/59480 examples...
# Processed 45500/59480 examples...
# Processed 45600/59480 examples...
# Processed 45700/59480 examples...
# Processed 45800/59480 examples...
# Processed 45900/59480 examples...
# Processed 46000/59480 examples...
# Processed 46100/59480 examples...
# Processed 46200/59480 examples...
# Processed 46300/59480 examples...
# Processed 46400/59480 examples...
# Processed 46500/59480 examples...
# Processed 46600/59480 examples...
# Processed 46700/59480 examples...
# Processed 46800/59480 examples...
# Processed 46900/59480 examples...
# Processed 47000/59480 examples...
# Processed 47100/59480 examples...
# Processed 47200/59480 examples...
# Processed 47300/59480 examples...
# Processed 47400/59480 examples...
# Processed 47500/59480 examples...
# Processed 47600/59480 examples...
# Processed 47700/59480 examples...
# Processed 47800/59480 examples...
# Processed 47900/59480 examples...
# Processed 48000/59480 examples...
# Processed 48100/59480 examples...
# Processed 48200/59480 examples...
# Processed 48300/59480 examples...
# Processed 48400/59480 examples...
# Processed 48500/59480 examples...
# Processed 48600/59480 examples...
# Processed 48700/59480 examples...
# Processed 48800/59480 examples...
# Processed 48900/59480 examples...
# Processed 49000/59480 examples...
# Processed 49100/59480 examples...
# Processed 49200/59480 examples...
# Processed 49300/59480 examples...
# Processed 49400/59480 examples...
# Processed 49500/59480 examples...
# Processed 49600/59480 examples...
# Processed 49700/59480 examples...
# Processed 49800/59480 examples...
# Processed 49900/59480 examples...
# Processed 50000/59480 examples...
# Processed 50100/59480 examples...
# Processed 50200/59480 examples...
# Processed 50300/59480 examples...
# Processed 50400/59480 examples...
# Processed 50500/59480 examples...
# Processed 50600/59480 examples...
# Processed 50700/59480 examples...
# Processed 50800/59480 examples...
# Processed 50900/59480 examples...
# Processed 51000/59480 examples...
# Processed 51100/59480 examples...
# Processed 51200/59480 examples...
# Processed 51300/59480 examples...
# Processed 51400/59480 examples...
# Processed 51500/59480 examples...
# Processed 51600/59480 examples...
# Processed 51700/59480 examples...
# Processed 51800/59480 examples...
# Processed 51900/59480 examples...
# Processed 52000/59480 examples...
# Processed 52100/59480 examples...
# Processed 52200/59480 examples...
# Processed 52300/59480 examples...
# Processed 52400/59480 examples...
# Processed 52500/59480 examples...
# Processed 52600/59480 examples...
# Processed 52700/59480 examples...
# Processed 52800/59480 examples...
# Processed 52900/59480 examples...
# Processed 53000/59480 examples...
# Processed 53100/59480 examples...
# Processed 53200/59480 examples...
# Processed 53300/59480 examples...
# Processed 53400/59480 examples...
# Processed 53500/59480 examples...
# Processed 53600/59480 examples...
# Processed 53700/59480 examples...
# Processed 53800/59480 examples...
# Processed 53900/59480 examples...
# Processed 54000/59480 examples...
# Processed 54100/59480 examples...
# Processed 54200/59480 examples...
# Processed 54300/59480 examples...
# Processed 54400/59480 examples...
# Processed 54500/59480 examples...
# Processed 54600/59480 examples...
# Processed 54700/59480 examples...
# Processed 54800/59480 examples...
# Processed 54900/59480 examples...
# Processed 55000/59480 examples...
# Processed 55100/59480 examples...
# Processed 55200/59480 examples...
# Processed 55300/59480 examples...
# Processed 55400/59480 examples...
# Processed 55500/59480 examples...
# Processed 55600/59480 examples...
# Processed 55700/59480 examples...
# Processed 55800/59480 examples...
# Processed 55900/59480 examples...
# Processed 56000/59480 examples...
# Processed 56100/59480 examples...
# Processed 56200/59480 examples...
# Processed 56300/59480 examples...
# Processed 56400/59480 examples...
# Processed 56500/59480 examples...
# Processed 56600/59480 examples...
# Processed 56700/59480 examples...
# Processed 56800/59480 examples...
# Processed 56900/59480 examples...
# Processed 57000/59480 examples...
# Processed 57100/59480 examples...
# Processed 57200/59480 examples...
# Processed 57300/59480 examples...
# Processed 57400/59480 examples...
# Processed 57500/59480 examples...
# Processed 57600/59480 examples...
# Processed 57700/59480 examples...
# Processed 57800/59480 examples...
# Processed 57900/59480 examples...
# Processed 58000/59480 examples...
# Processed 58100/59480 examples...
# Processed 58200/59480 examples...
# Processed 58300/59480 examples...
# Processed 58400/59480 examples...
# Processed 58500/59480 examples...
# Processed 58600/59480 examples...
# Processed 58700/59480 examples...
# Processed 58800/59480 examples...
# Processed 58900/59480 examples...
# Processed 59000/59480 examples...
# Processed 59100/59480 examples...
# Processed 59200/59480 examples...
# Processed 59300/59480 examples...
# Processed 59400/59480 examples...
#
# ----------------------------------------------------------------------
# INTENT CLASSIFICATION RESULTS
# ----------------------------------------------------------------------
# Accuracy:           0.8687
#
# Micro-averaged:
#   Precision:        0.8687
#   Recall:           0.8687
#   F1-Score:         0.8687
#
# Macro-averaged:
#   Precision:        0.8243
#   Recall:           0.8393
#   F1-Score:         0.8268
#
# Weighted-averaged:
#   Precision:        0.8718
#   Recall:           0.8687
#   F1-Score:         0.8685

# %%
# Parse annotated utterances to extract gold slots
import re

def parse_annotated_utterance(annot_utt):
    """
    Parse annotated utterance to extract gold slots
    Example: "wake me up at [time : 9 AM] on [date : friday]"
    Returns: [{'type': 'time', 'value': '9 AM'}, {'type': 'date', 'value': 'friday'}]
    """
    slots = []
    pattern = r'\[([^:]+):\s*([^\]]+)\]'
    matches = re.findall(pattern, annot_utt)
    for slot_type, slot_value in matches:
        slots.append({
            'type': slot_type.strip(),
            'value': slot_value.strip()
        })
    return slots

print("✓ parse_annotated_utterance function defined")
# Out:
# ✓ parse_annotated_utterance function defined

# %% [markdown]
# Cell 8: Slot Filling Evaluation (Entity-Level)

# %%
print("\n" + "="*70)
print("SLOT FILLING EVALUATION (Entity-Level)")
print("="*70)

all_true_slots = []
all_pred_slots = []

for i, example in enumerate(test_data):
    utterance = example['utt']
    annot_utt = example.get('annot_utt', '')

    # Extract ground truth slots
    true_slots = parse_annotated_utterance(annot_utt)

    # Predict slots
    pred_slots = extract_slots_crf(utterance)

    all_true_slots.append(true_slots)
    all_pred_slots.append(pred_slots)

    if (i + 1) % 100 == 0:
        print(f"Processed {i + 1}/{len(test_data)} examples...")

def compute_entity_metrics(true_slots_list, pred_slots_list):
    """Compute precision, recall, F1 for entity-level slot filling"""
    tp = 0  # True positives
    fp = 0  # False positives
    fn = 0  # False negatives

    for true_slots, pred_slots in zip(true_slots_list, pred_slots_list):
        true_set = {(s['type'], s['value']) for s in true_slots}
        pred_set = {(s['type'], s['value']) for s in pred_slots}

        tp += len(true_set & pred_set)
        fp += len(pred_set - true_set)
        fn += len(true_set - pred_set)

    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0

    return precision, recall, f1, tp, fp, fn

slot_precision, slot_recall, slot_f1, tp, fp, fn = compute_entity_metrics(
    all_true_slots, all_pred_slots
)

print("\n" + "-"*70)
print("SLOT FILLING RESULTS (Entity-Level)")
print("-"*70)
print(f"True Positives:     {tp}")
print(f"False Positives:    {fp}")
print(f"False Negatives:    {fn}")
print(f"\nPrecision:          {slot_precision:.4f}")
print(f"Recall:             {slot_recall:.4f}")
print(f"F1-Score:           {slot_f1:.4f}")
# Out:
# ======================================================================
# SLOT FILLING EVALUATION (Entity-Level)
# ======================================================================
# Processed 100/59480 examples...
# Processed 200/59480 examples...
# Processed 300/59480 examples...
# Processed 400/59480 examples...
# Processed 500/59480 examples...
# Processed 600/59480 examples...
# Processed 700/59480 examples...
# Processed 800/59480 examples...
# Processed 900/59480 examples...
# Processed 1000/59480 examples...
# Processed 1100/59480 examples...
# Processed 1200/59480 examples...
# Processed 1300/59480 examples...
# Processed 1400/59480 examples...
# Processed 1500/59480 examples...
# Processed 1600/59480 examples...
# Processed 1700/59480 examples...
# Processed 1800/59480 examples...
# Processed 1900/59480 examples...
# Processed 2000/59480 examples...
# Processed 2100/59480 examples...
# Processed 2200/59480 examples...
# Processed 2300/59480 examples...
# Processed 2400/59480 examples...
# Processed 2500/59480 examples...
# Processed 2600/59480 examples...
# Processed 2700/59480 examples...
# Processed 2800/59480 examples...
# Processed 2900/59480 examples...
# Processed 3000/59480 examples...
# Processed 3100/59480 examples...
# Processed 3200/59480 examples...
# Processed 3300/59480 examples...
# Processed 3400/59480 examples...
# Processed 3500/59480 examples...
# Processed 3600/59480 examples...
# Processed 3700/59480 examples...
# Processed 3800/59480 examples...
# Processed 3900/59480 examples...
# Processed 4000/59480 examples...
# Processed 4100/59480 examples...
# Processed 4200/59480 examples...
# Processed 4300/59480 examples...
# Processed 4400/59480 examples...
# Processed 4500/59480 examples...
# Processed 4600/59480 examples...
# Processed 4700/59480 examples...
# Processed 4800/59480 examples...
# Processed 4900/59480 examples...
# Processed 5000/59480 examples...
# Processed 5100/59480 examples...
# Processed 5200/59480 examples...
# Processed 5300/59480 examples...
# Processed 5400/59480 examples...
# Processed 5500/59480 examples...
# Processed 5600/59480 examples...
# Processed 5700/59480 examples...
# Processed 5800/59480 examples...
# Processed 5900/59480 examples...
# Processed 6000/59480 examples...
# Processed 6100/59480 examples...
# Processed 6200/59480 examples...
# Processed 6300/59480 examples...
# Processed 6400/59480 examples...
# Processed 6500/59480 examples...
# Processed 6600/59480 examples...
# Processed 6700/59480 examples...
# Processed 6800/59480 examples...
# Processed 6900/59480 examples...
# Processed 7000/59480 examples...
# Processed 7100/59480 examples...
# Processed 7200/59480 examples...
# Processed 7300/59480 examples...
# Processed 7400/59480 examples...
# Processed 7500/59480 examples...
# Processed 7600/59480 examples...
# Processed 7700/59480 examples...
# Processed 7800/59480 examples...
# Processed 7900/59480 examples...
# Processed 8000/59480 examples...
# Processed 8100/59480 examples...
# Processed 8200/59480 examples...
# Processed 8300/59480 examples...
# Processed 8400/59480 examples...
# Processed 8500/59480 examples...
# Processed 8600/59480 examples...
# Processed 8700/59480 examples...
# Processed 8800/59480 examples...
# Processed 8900/59480 examples...
# Processed 9000/59480 examples...
# Processed 9100/59480 examples...
# Processed 9200/59480 examples...
# Processed 9300/59480 examples...
# Processed 9400/59480 examples...
# Processed 9500/59480 examples...
# Processed 9600/59480 examples...
# Processed 9700/59480 examples...
# Processed 9800/59480 examples...
# Processed 9900/59480 examples...
# Processed 10000/59480 examples...
# Processed 10100/59480 examples...
# Processed 10200/59480 examples...
# Processed 10300/59480 examples...
# Processed 10400/59480 examples...
# Processed 10500/59480 examples...
# Processed 10600/59480 examples...
# Processed 10700/59480 examples...
# Processed 10800/59480 examples...
# Processed 10900/59480 examples...
# Processed 11000/59480 examples...
# Processed 11100/59480 examples...
# Processed 11200/59480 examples...
# Processed 11300/59480 examples...
# Processed 11400/59480 examples...
# Processed 11500/59480 examples...
# Processed 11600/59480 examples...
# Processed 11700/59480 examples...
# Processed 11800/59480 examples...
# Processed 11900/59480 examples...
# Processed 12000/59480 examples...
# Processed 12100/59480 examples...
# Processed 12200/59480 examples...
# Processed 12300/59480 examples...
# Processed 12400/59480 examples...
# Processed 12500/59480 examples...
# Processed 12600/59480 examples...
# Processed 12700/59480 examples...
# Processed 12800/59480 examples...
# Processed 12900/59480 examples...
# Processed 13000/59480 examples...
# Processed 13100/59480 examples...
# Processed 13200/59480 examples...
# Processed 13300/59480 examples...
# Processed 13400/59480 examples...
# Processed 13500/59480 examples...
# Processed 13600/59480 examples...
# Processed 13700/59480 examples...
# Processed 13800/59480 examples...
# Processed 13900/59480 examples...
# Processed 14000/59480 examples...
# Processed 14100/59480 examples...
# Processed 14200/59480 examples...
# Processed 14300/59480 examples...
# Processed 14400/59480 examples...
# Processed 14500/59480 examples...
# Processed 14600/59480 examples...
# Processed 14700/59480 examples...
# Processed 14800/59480 examples...
# Processed 14900/59480 examples...
# Processed 15000/59480 examples...
# Processed 15100/59480 examples...
# Processed 15200/59480 examples...
# Processed 15300/59480 examples...
# Processed 15400/59480 examples...
# Processed 15500/59480 examples...
# Processed 15600/59480 examples...
# Processed 15700/59480 examples...
# Processed 15800/59480 examples...
# Processed 15900/59480 examples...
# Processed 16000/59480 examples...
# Processed 16100/59480 examples...
# Processed 16200/59480 examples...
# Processed 16300/59480 examples...
# Processed 16400/59480 examples...
# Processed 16500/59480 examples...
# Processed 16600/59480 examples...
# Processed 16700/59480 examples...
# Processed 16800/59480 examples...
# Processed 16900/59480 examples...
# Processed 17000/59480 examples...
# Processed 17100/59480 examples...
# Processed 17200/59480 examples...
# Processed 17300/59480 examples...
# Processed 17400/59480 examples...
# Processed 17500/59480 examples...
# Processed 17600/59480 examples...
# Processed 17700/59480 examples...
# Processed 17800/59480 examples...
# Processed 17900/59480 examples...
# Processed 18000/59480 examples...
# Processed 18100/59480 examples...
# Processed 18200/59480 examples...
# Processed 18300/59480 examples...
# Processed 18400/59480 examples...
# Processed 18500/59480 examples...
# Processed 18600/59480 examples...
# Processed 18700/59480 examples...
# Processed 18800/59480 examples...
# Processed 18900/59480 examples...
# Processed 19000/59480 examples...
# Processed 19100/59480 examples...
# Processed 19200/59480 examples...
# Processed 19300/59480 examples...
# Processed 19400/59480 examples...
# Processed 19500/59480 examples...
# Processed 19600/59480 examples...
# Processed 19700/59480 examples...
# Processed 19800/59480 examples...
# Processed 19900/59480 examples...
# Processed 20000/59480 examples...
# Processed 20100/59480 examples...
# Processed 20200/59480 examples...
# Processed 20300/59480 examples...
# Processed 20400/59480 examples...
# Processed 20500/59480 examples...
# Processed 20600/59480 examples...
# Processed 20700/59480 examples...
# Processed 20800/59480 examples...
# Processed 20900/59480 examples...
# Processed 21000/59480 examples...
# Processed 21100/59480 examples...
# Processed 21200/59480 examples...
# Processed 21300/59480 examples...
# Processed 21400/59480 examples...
# Processed 21500/59480 examples...
# Processed 21600/59480 examples...
# Processed 21700/59480 examples...
# Processed 21800/59480 examples...
# Processed 21900/59480 examples...
# Processed 22000/59480 examples...
# Processed 22100/59480 examples...
# Processed 22200/59480 examples...
# Processed 22300/59480 examples...
# Processed 22400/59480 examples...
# Processed 22500/59480 examples...
# Processed 22600/59480 examples...
# Processed 22700/59480 examples...
# Processed 22800/59480 examples...
# Processed 22900/59480 examples...
# Processed 23000/59480 examples...
# Processed 23100/59480 examples...
# Processed 23200/59480 examples...
# Processed 23300/59480 examples...
# Processed 23400/59480 examples...
# Processed 23500/59480 examples...
# Processed 23600/59480 examples...
# Processed 23700/59480 examples...
# Processed 23800/59480 examples...
# Processed 23900/59480 examples...
# Processed 24000/59480 examples...
# Processed 24100/59480 examples...
# Processed 24200/59480 examples...
# Processed 24300/59480 examples...
# Processed 24400/59480 examples...
# Processed 24500/59480 examples...
# Processed 24600/59480 examples...
# Processed 24700/59480 examples...
# Processed 24800/59480 examples...
# Processed 24900/59480 examples...
# Processed 25000/59480 examples...
# Processed 25100/59480 examples...
# Processed 25200/59480 examples...
# Processed 25300/59480 examples...
# Processed 25400/59480 examples...
# Processed 25500/59480 examples...
# Processed 25600/59480 examples...
# Processed 25700/59480 examples...
# Processed 25800/59480 examples...
# Processed 25900/59480 examples...
# Processed 26000/59480 examples...
# Processed 26100/59480 examples...
# Processed 26200/59480 examples...
# Processed 26300/59480 examples...
# Processed 26400/59480 examples...
# Processed 26500/59480 examples...
# Processed 26600/59480 examples...
# Processed 26700/59480 examples...
# Processed 26800/59480 examples...
# Processed 26900/59480 examples...
# Processed 27000/59480 examples...
# Processed 27100/59480 examples...
# Processed 27200/59480 examples...
# Processed 27300/59480 examples...
# Processed 27400/59480 examples...
# Processed 27500/59480 examples...
# Processed 27600/59480 examples...
# Processed 27700/59480 examples...
# Processed 27800/59480 examples...
# Processed 27900/59480 examples...
# Processed 28000/59480 examples...
# Processed 28100/59480 examples...
# Processed 28200/59480 examples...
# Processed 28300/59480 examples...
# Processed 28400/59480 examples...
# Processed 28500/59480 examples...
# Processed 28600/59480 examples...
# Processed 28700/59480 examples...
# Processed 28800/59480 examples...
# Processed 28900/59480 examples...
# Processed 29000/59480 examples...
# Processed 29100/59480 examples...
# Processed 29200/59480 examples...
# Processed 29300/59480 examples...
# Processed 29400/59480 examples...
# Processed 29500/59480 examples...
# Processed 29600/59480 examples...
# Processed 29700/59480 examples...
# Processed 29800/59480 examples...
# Processed 29900/59480 examples...
# Processed 30000/59480 examples...
# Processed 30100/59480 examples...
# Processed 30200/59480 examples...
# Processed 30300/59480 examples...
# Processed 30400/59480 examples...
# Processed 30500/59480 examples...
# Processed 30600/59480 examples...
# Processed 30700/59480 examples...
# Processed 30800/59480 examples...
# Processed 30900/59480 examples...
# Processed 31000/59480 examples...
# Processed 31100/59480 examples...
# Processed 31200/59480 examples...
# Processed 31300/59480 examples...
# Processed 31400/59480 examples...
# Processed 31500/59480 examples...
# Processed 31600/59480 examples...
# Processed 31700/59480 examples...
# Processed 31800/59480 examples...
# Processed 31900/59480 examples...
# Processed 32000/59480 examples...
# Processed 32100/59480 examples...
# Processed 32200/59480 examples...
# Processed 32300/59480 examples...
# Processed 32400/59480 examples...
# Processed 32500/59480 examples...
# Processed 32600/59480 examples...
# Processed 32700/59480 examples...
# Processed 32800/59480 examples...
# Processed 32900/59480 examples...
# Processed 33000/59480 examples...
# Processed 33100/59480 examples...
# Processed 33200/59480 examples...
# Processed 33300/59480 examples...
# Processed 33400/59480 examples...
# Processed 33500/59480 examples...
# Processed 33600/59480 examples...
# Processed 33700/59480 examples...
# Processed 33800/59480 examples...
# Processed 33900/59480 examples...
# Processed 34000/59480 examples...
# Processed 34100/59480 examples...
# Processed 34200/59480 examples...
# Processed 34300/59480 examples...
# Processed 34400/59480 examples...
# Processed 34500/59480 examples...
# Processed 34600/59480 examples...
# Processed 34700/59480 examples...
# Processed 34800/59480 examples...
# Processed 34900/59480 examples...
# Processed 35000/59480 examples...
# Processed 35100/59480 examples...
# Processed 35200/59480 examples...
# Processed 35300/59480 examples...
# Processed 35400/59480 examples...
# Processed 35500/59480 examples...
# Processed 35600/59480 examples...
# Processed 35700/59480 examples...
# Processed 35800/59480 examples...
# Processed 35900/59480 examples...
# Processed 36000/59480 examples...
# Processed 36100/59480 examples...
# Processed 36200/59480 examples...
# Processed 36300/59480 examples...
# Processed 36400/59480 examples...
# Processed 36500/59480 examples...
# Processed 36600/59480 examples...
# Processed 36700/59480 examples...
# Processed 36800/59480 examples...
# Processed 36900/59480 examples...
# Processed 37000/59480 examples...
# Processed 37100/59480 examples...
# Processed 37200/59480 examples...
# Processed 37300/59480 examples...
# Processed 37400/59480 examples...
# Processed 37500/59480 examples...
# Processed 37600/59480 examples...
# Processed 37700/59480 examples...
# Processed 37800/59480 examples...
# Processed 37900/59480 examples...
# Processed 38000/59480 examples...
# Processed 38100/59480 examples...
# Processed 38200/59480 examples...
# Processed 38300/59480 examples...
# Processed 38400/59480 examples...
# Processed 38500/59480 examples...
# Processed 38600/59480 examples...
# Processed 38700/59480 examples...
# Processed 38800/59480 examples...
# Processed 38900/59480 examples...
# Processed 39000/59480 examples...
# Processed 39100/59480 examples...
# Processed 39200/59480 examples...
# Processed 39300/59480 examples...
# Processed 39400/59480 examples...
# Processed 39500/59480 examples...
# Processed 39600/59480 examples...
# Processed 39700/59480 examples...
# Processed 39800/59480 examples...
# Processed 39900/59480 examples...
# Processed 40000/59480 examples...
# Processed 40100/59480 examples...
# Processed 40200/59480 examples...
# Processed 40300/59480 examples...
# Processed 40400/59480 examples...
# Processed 40500/59480 examples...
# Processed 40600/59480 examples...
# Processed 40700/59480 examples...
# Processed 40800/59480 examples...
# Processed 40900/59480 examples...
# Processed 41000/59480 examples...
# Processed 41100/59480 examples...
# Processed 41200/59480 examples...
# Processed 41300/59480 examples...
# Processed 41400/59480 examples...
# Processed 41500/59480 examples...
# Processed 41600/59480 examples...
# Processed 41700/59480 examples...
# Processed 41800/59480 examples...
# Processed 41900/59480 examples...
# Processed 42000/59480 examples...
# Processed 42100/59480 examples...
# Processed 42200/59480 examples...
# Processed 42300/59480 examples...
# Processed 42400/59480 examples...
# Processed 42500/59480 examples...
# Processed 42600/59480 examples...
# Processed 42700/59480 examples...
# Processed 42800/59480 examples...
# Processed 42900/59480 examples...
# Processed 43000/59480 examples...
# Processed 43100/59480 examples...
# Processed 43200/59480 examples...
# Processed 43300/59480 examples...
# Processed 43400/59480 examples...
# Processed 43500/59480 examples...
# Processed 43600/59480 examples...
# Processed 43700/59480 examples...
# Processed 43800/59480 examples...
# Processed 43900/59480 examples...
# Processed 44000/59480 examples...
# Processed 44100/59480 examples...
# Processed 44200/59480 examples...
# Processed 44300/59480 examples...
# Processed 44400/59480 examples...
# Processed 44500/59480 examples...
# Processed 44600/59480 examples...
# Processed 44700/59480 examples...
# Processed 44800/59480 examples...
# Processed 44900/59480 examples...
# Processed 45000/59480 examples...
# Processed 45100/59480 examples...
# Processed 45200/59480 examples...
# Processed 45300/59480 examples...
# Processed 45400/59480 examples...
# Processed 45500/59480 examples...
# Processed 45600/59480 examples...
# Processed 45700/59480 examples...
# Processed 45800/59480 examples...
# Processed 45900/59480 examples...
# Processed 46000/59480 examples...
# Processed 46100/59480 examples...
# Processed 46200/59480 examples...
# Processed 46300/59480 examples...
# Processed 46400/59480 examples...
# Processed 46500/59480 examples...
# Processed 46600/59480 examples...
# Processed 46700/59480 examples...
# Processed 46800/59480 examples...
# Processed 46900/59480 examples...
# Processed 47000/59480 examples...
# Processed 47100/59480 examples...
# Processed 47200/59480 examples...
# Processed 47300/59480 examples...
# Processed 47400/59480 examples...
# Processed 47500/59480 examples...
# Processed 47600/59480 examples...
# Processed 47700/59480 examples...
# Processed 47800/59480 examples...
# Processed 47900/59480 examples...
# Processed 48000/59480 examples...
# Processed 48100/59480 examples...
# Processed 48200/59480 examples...
# Processed 48300/59480 examples...
# Processed 48400/59480 examples...
# Processed 48500/59480 examples...
# Processed 48600/59480 examples...
# Processed 48700/59480 examples...
# Processed 48800/59480 examples...
# Processed 48900/59480 examples...
# Processed 49000/59480 examples...
# Processed 49100/59480 examples...
# Processed 49200/59480 examples...
# Processed 49300/59480 examples...
# Processed 49400/59480 examples...
# Processed 49500/59480 examples...
# Processed 49600/59480 examples...
# Processed 49700/59480 examples...
# Processed 49800/59480 examples...
# Processed 49900/59480 examples...
# Processed 50000/59480 examples...
# Processed 50100/59480 examples...
# Processed 50200/59480 examples...
# Processed 50300/59480 examples...
# Processed 50400/59480 examples...
# Processed 50500/59480 examples...
# Processed 50600/59480 examples...
# Processed 50700/59480 examples...
# Processed 50800/59480 examples...
# Processed 50900/59480 examples...
# Processed 51000/59480 examples...
# Processed 51100/59480 examples...
# Processed 51200/59480 examples...
# Processed 51300/59480 examples...
# Processed 51400/59480 examples...
# Processed 51500/59480 examples...
# Processed 51600/59480 examples...
# Processed 51700/59480 examples...
# Processed 51800/59480 examples...
# Processed 51900/59480 examples...
# Processed 52000/59480 examples...
# Processed 52100/59480 examples...
# Processed 52200/59480 examples...
# Processed 52300/59480 examples...
# Processed 52400/59480 examples...
# Processed 52500/59480 examples...
# Processed 52600/59480 examples...
# Processed 52700/59480 examples...
# Processed 52800/59480 examples...
# Processed 52900/59480 examples...
# Processed 53000/59480 examples...
# Processed 53100/59480 examples...
# Processed 53200/59480 examples...
# Processed 53300/59480 examples...
# Processed 53400/59480 examples...
# Processed 53500/59480 examples...
# Processed 53600/59480 examples...
# Processed 53700/59480 examples...
# Processed 53800/59480 examples...
# Processed 53900/59480 examples...
# Processed 54000/59480 examples...
# Processed 54100/59480 examples...
# Processed 54200/59480 examples...
# Processed 54300/59480 examples...
# Processed 54400/59480 examples...
# Processed 54500/59480 examples...
# Processed 54600/59480 examples...
# Processed 54700/59480 examples...
# Processed 54800/59480 examples...
# Processed 54900/59480 examples...
# Processed 55000/59480 examples...
# Processed 55100/59480 examples...
# Processed 55200/59480 examples...
# Processed 55300/59480 examples...
# Processed 55400/59480 examples...
# Processed 55500/59480 examples...
# Processed 55600/59480 examples...
# Processed 55700/59480 examples...
# Processed 55800/59480 examples...
# Processed 55900/59480 examples...
# Processed 56000/59480 examples...
# Processed 56100/59480 examples...
# Processed 56200/59480 examples...
# Processed 56300/59480 examples...
# Processed 56400/59480 examples...
# Processed 56500/59480 examples...
# Processed 56600/59480 examples...
# Processed 56700/59480 examples...
# Processed 56800/59480 examples...
# Processed 56900/59480 examples...
# Processed 57000/59480 examples...
# Processed 57100/59480 examples...
# Processed 57200/59480 examples...
# Processed 57300/59480 examples...
# Processed 57400/59480 examples...
# Processed 57500/59480 examples...
# Processed 57600/59480 examples...
# Processed 57700/59480 examples...
# Processed 57800/59480 examples...
# Processed 57900/59480 examples...
# Processed 58000/59480 examples...
# Processed 58100/59480 examples...
# Processed 58200/59480 examples...
# Processed 58300/59480 examples...
# Processed 58400/59480 examples...
# Processed 58500/59480 examples...
# Processed 58600/59480 examples...
# Processed 58700/59480 examples...
# Processed 58800/59480 examples...
# Processed 58900/59480 examples...
# Processed 59000/59480 examples...
# Processed 59100/59480 examples...
# Processed 59200/59480 examples...
# Processed 59300/59480 examples...
# Processed 59400/59480 examples...
#
# ----------------------------------------------------------------------
# SLOT FILLING RESULTS (Entity-Level)
# ----------------------------------------------------------------------
# True Positives:     40072
# False Positives:    16125
# False Negatives:    15891
#
# Precision:          0.7131
# Recall:             0.7160
# F1-Score:           0.7146

# %% [markdown]
# Cell 9: Per-Slot-Type Metrics

# %%
print("\n" + "="*70)
print("PER-SLOT-TYPE METRICS")
print("="*70)

def compute_per_type_metrics(true_slots_list, pred_slots_list):
    """Compute metrics for each slot type separately"""
    slot_type_stats = defaultdict(lambda: {'tp': 0, 'fp': 0, 'fn': 0})

    for true_slots, pred_slots in zip(true_slots_list, pred_slots_list):
        true_by_type = defaultdict(set)
        pred_by_type = defaultdict(set)

        for slot in true_slots:
            true_by_type[slot['type']].add(slot['value'])

        for slot in pred_slots:
            pred_by_type[slot['type']].add(slot['value'])

        all_types = set(true_by_type.keys()) | set(pred_by_type.keys())

        for slot_type in all_types:
            true_vals = true_by_type[slot_type]
            pred_vals = pred_by_type[slot_type]

            slot_type_stats[slot_type]['tp'] += len(true_vals & pred_vals)
            slot_type_stats[slot_type]['fp'] += len(pred_vals - true_vals)
            slot_type_stats[slot_type]['fn'] += len(true_vals - pred_vals)

    per_type_metrics = {}
    for slot_type, stats in slot_type_stats.items():
        tp = stats['tp']
        fp = stats['fp']
        fn = stats['fn']

        p = tp / (tp + fp) if (tp + fp) > 0 else 0
        r = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1 = 2 * p * r / (p + r) if (p + r) > 0 else 0

        per_type_metrics[slot_type] = {
            'precision': p,
            'recall': r,
            'f1': f1,
            'support': tp + fn
        }

    return per_type_metrics

per_type_metrics = compute_per_type_metrics(all_true_slots, all_pred_slots)

print(f"\n{'Slot Type':<20} {'Precision':<12} {'Recall':<12} {'F1':<12} {'Support':<10}")
print("-"*70)

# FIXED LINE HERE:
sorted_types = sorted(per_type_metrics.items(), key=lambda x: x[1]['support'], reverse=True)
for slot_type, metrics in sorted_types[:15]:  # Top 15
    print(f"{slot_type:<20} {metrics['precision']:<12.4f} {metrics['recall']:<12.4f} "
          f"{metrics['f1']:<12.4f} {metrics['support']:<10}")

# Macro-average across slot types
slot_macro_p = np.mean([m['precision'] for m in per_type_metrics.values()])
slot_macro_r = np.mean([m['recall'] for m in per_type_metrics.values()])
slot_macro_f1 = np.mean([m['f1'] for m in per_type_metrics.values()])

print("\n" + "-"*70)
print("SLOT FILLING - MACRO-AVERAGED (across slot types)")
print("-"*70)
print(f"Macro Precision:    {slot_macro_p:.4f}")
print(f"Macro Recall:       {slot_macro_r:.4f}")
print(f"Macro F1-Score:     {slot_macro_f1:.4f}")
# Out:
# ======================================================================
# PER-SLOT-TYPE METRICS
# ======================================================================
#
# Slot Type            Precision    Recall       F1           Support
# ----------------------------------------------------------------------
# date                 0.7660       0.8014       0.7833       8300
# place_name           0.7741       0.7272       0.7499       5583
# event_name           0.7050       0.6577       0.6805       5185
# person               0.7521       0.8209       0.7850       4349
# time                 0.6772       0.6237       0.6493       3827
# media_type           0.7976       0.7676       0.7823       2552
# business_name        0.7370       0.7134       0.7250       1835
# weather_descriptor   0.7238       0.6957       0.7095       1620
# food_type            0.6524       0.7140       0.6818       1430
# transport_type       0.8580       0.8447       0.8513       1281
# list_name            0.6928       0.6766       0.6846       1203
# artist_name          0.6834       0.7303       0.7061       1194
# timeofday            0.7139       0.6855       0.6994       1183
# relation             0.7200       0.7673       0.7429       1173
# house_place          0.7527       0.7997       0.7754       1153
#
# ----------------------------------------------------------------------
# SLOT FILLING - MACRO-AVERAGED (across slot types)
# ----------------------------------------------------------------------
# Macro Precision:    0.5876
# Macro Recall:       0.5989
# Macro F1-Score:     0.5893

# %% [markdown]
# Cell 10: Final Summary and Save Results

# %%
print("\n" + "="*70)
print("FINAL SUMMARY")
print("="*70)
print(f"\nIntent Classification:")
print(f"  Accuracy:         {intent_accuracy:.4f}")
print(f"  Micro F1:         {intent_micro_f1:.4f}")
print(f"  Macro F1:         {intent_macro_f1:.4f}")
print(f"\nSlot Filling (Entity-Level):")
print(f"  Precision:        {slot_precision:.4f}")
print(f"  Recall:           {slot_recall:.4f}")
print(f"  F1-Score:         {slot_f1:.4f}")
print(f"\nSlot Filling (Macro across types):")
print(f"  Macro Precision:  {slot_macro_p:.4f}")
print(f"  Macro Recall:     {slot_macro_r:.4f}")
print(f"  Macro F1:         {slot_macro_f1:.4f}")
print("\n" + "="*70)

# Save results to JSON
results = {
    'intent_classification': {
        'accuracy': float(intent_accuracy),
        'micro': {
            'precision': float(intent_micro_p),
            'recall': float(intent_micro_r),
            'f1': float(intent_micro_f1)
        },
        'macro': {
            'precision': float(intent_macro_p),
            'recall': float(intent_macro_r),
            'f1': float(intent_macro_f1)
        },
        'weighted': {
            'precision': float(intent_weighted_p),
            'recall': float(intent_weighted_r),
            'f1': float(intent_weighted_f1)
        }
    },
    'slot_filling': {
        'entity_level': {
            'precision': float(slot_precision),
            'recall': float(slot_recall),
            'f1': float(slot_f1),
            'true_positives': int(tp),
            'false_positives': int(fp),
            'false_negatives': int(fn)
        },
        'macro_across_types': {
            'precision': float(slot_macro_p),
            'recall': float(slot_macro_r),
            'f1': float(slot_macro_f1)
        },
        'per_type_metrics': {k: {kk: float(vv) if kk != 'support' else int(vv)
                                  for kk, vv in v.items()}
                             for k, v in per_type_metrics.items()}
    }
}

results_path = f"{drive_path}/evaluation_results.json"
with open(results_path, 'w') as f:
    json.dump(results, f, indent=2)

print(f"\n✓ Results saved to: {results_path}")
# Out:
# ======================================================================
# FINAL SUMMARY
# ======================================================================
#
# Intent Classification:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1223974802.py in <cell line: 0>()
#       3 print("="*70)
#       4 print(f"\nIntent Classification:")
# ----> 5 print(f"  Accuracy:         {intent_accuracy:.4f}")
#       6 print(f"  Micro F1:         {intent_micro_f1:.4f}")
#       7 print(f"  Macro F1:         {intent_macro_f1:.4f}")
#
# NameError: name 'intent_accuracy' is not defined
